# %% [markdown]
# # Thresholding
#
# Thresholding creates a binary image from a grayscale image [1]_.
#
# .. [1] https://en.wikipedia.org/wiki/Thresholding_%28image_processing%29
#
# .. seealso::
#     A more comprehensive presentation on
#     `sphx_glr_auto_examples_applications_plot_thresholding_guide.py`

# %%
import matplotlib.pyplot as plt
from skimage import data
from skimage.filters import threshold_otsu

# %% [markdown]
# __Otsu's method__ [2]_ calculates an "optimal" threshold (marked by a red line in the histogram) by maximizing the variance between two classes of pixels, which are separated by the threshold. Equivalently, this threshold minimizes the intra-class variance.
#
# .. [2] https://en.wikipedia.org/wiki/Otsu's_method

# %%
image = data.camera()
thresh = threshold_otsu(image)
binary = image > thresh

fig, axes = plt.subplots(ncols=3, figsize=(8, 2.5))
ax = axes.ravel()
ax[0] = plt.subplot(1, 3, 1)
ax[1] = plt.subplot(1, 3, 2)
ax[2] = plt.subplot(1, 3, 3, sharex=ax[0], sharey=ax[0])

ax[0].imshow(image, cmap=plt.cm.gray)
ax[0].set_title('Original')
ax[0].axis('off')

ax[1].hist(image.ravel(), bins=256)
ax[1].set_title('Histogram')
ax[1].axvline(thresh, color='r')

ax[2].imshow(binary, cmap=plt.cm.gray)
ax[2].set_title('Thresholded')
ax[2].axis('off')

plt.show()
# Out:
# /tmp/ipykernel_193824/1528479257.py:9: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax[2] = plt.subplot(1, 3, 3, sharex=ax[0], sharey=ax[0])

# %% [markdown]
# Scikit-image includes a function to benchmark its thresholding algorithms.

# %%
from skimage.filters import try_all_threshold

img = data.page()

fig, ax = try_all_threshold(img, figsize=(10, 8), verbose=False)
plt.show()
